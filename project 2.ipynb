# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('ds_salaries.csv')
df.head(50)
# Out:
#     work_year experience_level employment_type  \
# 0        2023               SE              FT
# 1        2023               MI              CT
# 2        2023               MI              CT
# 3        2023               SE              FT
# 4        2023               SE              FT
# 5        2023               SE              FT
# 6        2023               SE              FT
# 7        2023               SE              FT
# 8        2023               SE              FT
# 9        2023               SE              FT
# 10       2023               SE              FT
# 11       2023               SE              FT
# 12       2023               SE              FT
# 13       2023               EN              FT
# 14       2023               EN              FT
# 15       2023               SE              FT
# 16       2023               SE              FT
# 17       2023               SE              FT
# 18       2023               SE              FT
# ...

# %%
df.drop(['salary','salary_currency'],axis=1,inplace=True)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df['company_size'].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
df['experience_level']=df['experience_level'].replace('SE','Senior level')
df['experience_level']=df['experience_level'].replace('MI','Med level')
df['experience_level']=df['experience_level'].replace('EN','Entry level')
df['experience_level']=df['experience_level'].replace('EX','Expert level')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level              FT  Principal Data Scientist
# 1          2023        Med level              CT               ML Engineer
# 2          2023        Med level              CT               ML Engineer
# 3          2023     Senior level              FT            Data Scientist
# 4          2023     Senior level              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level              FT            Data Scientist
# 3751       2021        Med level              FT  Principal Data Scientist
# 3752       2020      Entry level              FT            Data Scientist
# 3753       2020      Entry level              CT     Business Data Analyst
# 3754       2021     Senior level              FT      Data Science Manager
#
# ...

# %%
df['employment_type']=df['employment_type'].replace('FT','Full time')
df['employment_type']=df['employment_type'].replace('CT','Contract')
df['employment_type']=df['employment_type'].replace('FL','Freelance')
df['employment_type']=df['employment_type'].replace('PT','Part time')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %%
df['remote_ratio']=df['remote_ratio'].replace(100,'Remotly')
df['remote_ratio']=df['remote_ratio'].replace(50,'Hybrid')
df['remote_ratio']=df['remote_ratio'].replace(0,'On-site')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %%
df['company_size']=df['company_size'].replace('L','Large')
df['company_size']=df['company_size'].replace('S','Small')
df['company_size']=df['company_size'].replace('M','Medium')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %%
df.shape
# Out:
# (3755, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary_in_usd       3755 non-null   int64
#  5   employee_residence  3755 non-null   object
#  6   remote_ratio        3755 non-null   object
#  7   company_location    3755 non-null   object
#  8   company_size        3755 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 264.1+ KB

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.describe()
# Out:
#          work_year  salary_in_usd
# count  3755.000000    3755.000000
# mean   2022.373635  137570.389880
# std       0.691448   63055.625278
# min    2020.000000    5132.000000
# 25%    2022.000000   95000.000000
# 50%    2022.000000  135000.000000
# 75%    2023.000000  175000.000000
# max    2023.000000  450000.000000

# %%
duplicates=df.duplicated()
if duplicates.any():
    print('Duplication is found !!')
    row_with_duplication =df[duplicates]
    print(row_with_duplication)
else :
    print('No Duplication Found !!')
# Out:
# Duplication is found !!
#       work_year experience_level employment_type           job_title  \
# 115        2023     Senior level       Full time      Data Scientist
# 123        2023     Senior level       Full time  Analytics Engineer
# 153        2023        Med level       Full time       Data Engineer
# 154        2023        Med level       Full time       Data Engineer
# 160        2023     Senior level       Full time       Data Engineer
# ...         ...              ...             ...                 ...
# 3439       2022        Med level       Full time      Data Scientist
# 3440       2022     Senior level       Full time       Data Engineer
# 3441       2022     Senior level       Full time       Data Engineer
# 3586       2021        Med level       Full time       Data Engineer
# 3709       2021        Med level       Full time      Data Scientist
#
#       salary_in_usd employee_residence remote_ratio company_location  \
# ...

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %%
Jobs=df['job_title'].value_counts()

# %%
Jobs
# Out:
# Data Engineer                          1040
# Data Scientist                          840
# Data Analyst                            612
# Machine Learning Engineer               289
# Analytics Engineer                      103
#                                        ...
# Principal Machine Learning Engineer       1
# Azure Data Engineer                       1
# Manager Data Management                   1
# Marketing Data Engineer                   1
# Finance Data Analyst                      1
# Name: job_title, Length: 93, dtype: int64

# %%
top15_job=Jobs[:15]
top15_job
# Out:
# Data Engineer                 1040
# Data Scientist                 840
# Data Analyst                   612
# Machine Learning Engineer      289
# Analytics Engineer             103
# Data Architect                 101
# Research Scientist              82
# Data Science Manager            58
# Applied Scientist               58
# Research Engineer               37
# ML Engineer                     34
# Data Manager                    29
# Machine Learning Scientist      26
# Data Science Consultant         24
# Data Analytics Manager          22
# Name: job_title, dtype: int64

# %%
counts=np.array(top15_job)

# %%
job_title=['Data Engineer','Data Scientist','Data Analyst','ML ','AE','DA','Research Scientist','DS Manager','Applied Scientist','Researcher','ML','DM','ML','DS Consultant','DA Manager']

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=job_title,y=counts,data=df)
plt.show()

# %% [markdown]
# # Average salaries based on job title

# %%
avg_salary=df.groupby('job_title')['salary_in_usd'].mean()

# %%
avg_salary
# Out:
# job_title
# 3D Computer Vision Researcher     21352.250000
# AI Developer                     136666.090909
# AI Programmer                     55000.000000
# AI Scientist                     110120.875000
# Analytics Engineer               152368.631068
#                                      ...
# Research Engineer                163108.378378
# Research Scientist               161214.195122
# Software Data Engineer            62510.000000
# Staff Data Analyst                15000.000000
# Staff Data Scientist             105000.000000
# Name: salary_in_usd, Length: 93, dtype: float64

# %%
avg_salary.idxmax()
# Out:
# 'Data Science Tech Lead'

# %%
avg_salary['Data Science Tech Lead']
# Out:
# 375000.0

# %%
avg_salary.argmax()
# Out:
# 46

# %%
avg_salary[46]
# Out:
# 375000.0

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %% [markdown]
# # experience_level

# %%
#number of jobs based on experience_level
#Average Salaries based on experience_level

# %% [markdown]
# # number of jobs based on experience_level

# %%
df['experience_level'].value_counts()
# Out:
# Senior level    2516
# Med level        805
# Entry level      320
# Expert level     114
# Name: experience_level, dtype: int64

# %%
df['experience_level'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Average Salaries based on experience_level

# %%
exper_level=df.groupby('experience_level')['salary_in_usd'].mean()

# %%
exper_level
# Out:
# experience_level
# Entry level      78546.284375
# Expert level    194930.929825
# Med level       104525.939130
# Senior level    153051.071542
# Name: salary_in_usd, dtype: float64

# %%
df.groupby('experience_level')['salary_in_usd'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='experience_level'>

# %%
exper_sal=['Entry level','Expert level','Med level','Senior level']

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=exper_sal,y=exper_level)
plt.title('Average Salaries based on experience_level')
plt.xlabel('Experience_level')
plt.ylabel('Salary')
plt.show()

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %%
# number of jobs based on employment_type
#Average Salaries based on employment_type

# %% [markdown]
# # number of jobs based on employment_type

# %%
df['employment_type'].value_counts()
# Out:
# Full time    3718
# Part time      17
# Contract       10
# Freelance      10
# Name: employment_type, dtype: int64

# %%
df['employment_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Average Salaries based on employment_type

# %%
employ_sal=df.groupby('employment_type')['salary_in_usd'].mean()

# %%
employ_sal
# Out:
# employment_type
# Contract     113446.900000
# Freelance     51807.800000
# Full time    138314.199570
# Part time     39533.705882
# Name: salary_in_usd, dtype: float64

# %%
counts=np.array(employ_sal)

# %%
counts
# Out:
# array([113446.9       ,  51807.8       , 138314.19956966,  39533.70588235])

# %%
employee_type=['Contract','Freelance','Full time ','Part time']

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=employee_type,y=counts)
plt.title('Average Salaries based on employment_type')
plt.xlabel('Employment_type')
plt.ylabel('Salary')
plt.show()

# %%
df.groupby('employment_type')['salary_in_usd'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='employment_type'>

# %%
# number of jobs based on remote_ratio
#Average Salaries based on remote_ratio

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %% [markdown]
# # number of jobs based on remote_ratio

# %%
df['remote_ratio'].value_counts()
# Out:
# On-site    1923
# Remotly    1643
# Hybrid      189
# Name: remote_ratio, dtype: int64

# %%
df['remote_ratio'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Average Salaries based on remote_ratio

# %%
df.groupby('remote_ratio')['salary_in_usd'].mean()
# Out:
# remote_ratio
# Hybrid      78400.687831
# On-site    144316.202288
# Remotly    136481.452830
# Name: salary_in_usd, dtype: float64

# %%
df.groupby('remote_ratio')['salary_in_usd'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='remote_ratio'>

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior level       Full time  Principal Data Scientist
# 1          2023        Med level        Contract               ML Engineer
# 2          2023        Med level        Contract               ML Engineer
# 3          2023     Senior level       Full time            Data Scientist
# 4          2023     Senior level       Full time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior level       Full time            Data Scientist
# 3751       2021        Med level       Full time  Principal Data Scientist
# 3752       2020      Entry level       Full time            Data Scientist
# 3753       2020      Entry level        Contract     Business Data Analyst
# 3754       2021     Senior level       Full time      Data Science Manager
#
# ...

# %%
# number of jobs based on company_location
#Average Salaries based on company_location

# %% [markdown]
# # number of jobs based on company_location

# %%
df['company_location'].value_counts()
# Out:
# US    3040
# GB     172
# CA      87
# ES      77
# IN      58
#       ...
# MK       1
# BS       1
# IR       1
# CR       1
# MT       1
# Name: company_location, Length: 72, dtype: int64

# %% [markdown]
# # Average Salaries based on company_location

# %%
avg_company_sal=df.groupby('company_location')['salary_in_usd'].mean()

# %%
avg_company_sal
# Out:
# company_location
# AE    100000.000000
# AL     10000.000000
# AM     50000.000000
# AR     25000.000000
# AS     29351.000000
#           ...
# TH     23064.333333
# TR     19058.000000
# UA     57850.000000
# US    151822.009539
# VN     12000.000000
# Name: salary_in_usd, Length: 72, dtype: float64

# %%
top15_country=avg_company_sal[:15]

# %%
top15_country
# Out:
# company_location
# AE    100000.000000
# AL     10000.000000
# AM     50000.000000
# AR     25000.000000
# AS     29351.000000
# AT     71354.833333
# AU     80033.428571
# BA    120000.000000
# BE     76864.750000
# BO      7500.000000
# BR     40579.200000
# BS     45555.000000
# CA    131917.689655
# CF     48609.000000
# CH     81722.000000
# Name: salary_in_usd, dtype: float64

# %%
# number of jobs based on company_size
#Average Salaries based on company_size

# %% [markdown]
# # number of jobs based on company_size

# %%
c=df['company_size'].value_counts()

# %%
c
# Out:
# Medium    3153
# Large      454
# Small      148
# Name: company_size, dtype: int64

# %%
com_size=['Medium','Large','Small']

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=com_size,y=c)
plt.title('number of jobs based on company_size')
plt.xlabel('company_size')
plt.ylabel('number of jobs')
plt.show()

# %% [markdown]
# # Average Salaries based on company_size

# %%
df.groupby('company_size')['salary_in_usd'].mean()
# Out:
# company_size
# Large     118300.982379
# Medium    143130.548367
# Small      78226.682432
# Name: salary_in_usd, dtype: float64

# %%
df.groupby('company_size')['salary_in_usd'].mean().plot(kind='bar')
plt.show()

# %%
# number of jobs based on work_year
#Average Salaries based on work_year

# %% [markdown]
# # number of jobs based on work_year

# %%
year_work=df['work_year'].value_counts()

# %%
year_work
# Out:
# 2023    1785
# 2022    1664
# 2021     230
# 2020      76
# Name: work_year, dtype: int64

# %%
work_year_count=list(year_work)
work_year_count.reverse()

# %%
work_year_count
# Out:
# [76, 230, 1664, 1785]

# %%
year_num=['2020','2021','2022','2023']

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=year_num,y=work_year_count)
plt.title('number of jobs according to work year')
plt.show()

# %%
df['work_year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Average Salaries based on work_year

# %%
avg_salary_year=df.groupby('work_year')['salary_in_usd'].mean()

# %%
avg_salary_year
# Out:
# work_year
# 2020     92302.631579
# 2021     94087.208696
# 2022    133338.620793
# 2023    149045.541176
# Name: salary_in_usd, dtype: float64

# %%
year_num=['2020','2021','2022','2023']

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=year_num,y=avg_salary_year)
plt.title('number of jobs according to work year')
plt.show()
